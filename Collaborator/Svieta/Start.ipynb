# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd 
data = pd.read_csv("./indian_liver_patient 2.csv")
data
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# 1                          64                         100             7.5
# 2                          60                          68             7.0
# 3                          14                          20             6.8
# 4                          27                          59             7.3
# ..                        ...                         ...             ...
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0        3.3                        0.90        1
# 1        3.2                        0.74        1
# 2        3.3                        0.89        1
# 3        3.4                        1.00        1
# 4        2.4                        0.40        1
# ..       ...                         ...      ...
# 578      1.6                        0.37        2
# 579      3.2                        1.10        1
# 580      3.2                        1.00        1
# 581      3.4                        1.00        1
# 582      4.4                        1.50        2
#
# [583 rows x 11 columns]

# %%
import pandas_datareader as pdr 
import matplotlib.pyplot as plt 
df = pdr.get_data_fred('GS10')
plt.plot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import pandas_datareader as pdr 
from pandas_datareader import wb 
all_indicators = pdr.wb.get_indicators()
all_indicators.iloc[:5,:2]
# Out:
#                      id                                     name
# 0    1.0.HCount.1.90usd          Poverty Headcount ($1.90 a day)
# 1     1.0.HCount.2.5usd          Poverty Headcount ($2.50 a day)
# 2  1.0.HCount.Mid10to50    Middle Class ($10-50 a day) Headcount
# 3       1.0.HCount.Ofcl  Official Moderate Poverty Rate-National
# 4   1.0.HCount.Poor4uds             Poverty Headcount ($4 a day)

# %%
indicator_search = pdr.wb.search("life expectancy")
indicator_search.iloc[:5,:2]
# Out:
#                       id                                               name
# 15862        SE.SCH.LIFE  School life expectancy, primary to tertiary, b...
# 15863     SE.SCH.LIFE.FE  School life expectancy, primary to tertiary, f...
# 15864     SE.SCH.LIFE.MA  School life expectancy, primary to tertiary, m...
# 17464  SP.DYN.LE00.FE.IN           Life expectancy at birth, female (years)
# 17465     SP.DYN.LE00.IN            Life expectancy at birth, total (years)

# %%
all_countries = pdr.wb.get_countries() 
all_countries.loc[0:5 , ['name', 'capitalCity', 'iso2c']]
# Out:
#                           name capitalCity iso2c
# 0                        Aruba  Oranjestad    AW
# 1  Africa Eastern and Southern                ZH
# 2                  Afghanistan       Kabul    AF
# 3                       Africa                A9
# 4   Africa Western and Central                ZI
# 5                       Angola      Luanda    AO

# %%
result_data = pdr.wb.download(indicator = "SP.DYN.LEO.IN", start='1980', end='1999')
result_data
# Out:
# /Users/anbschool0026/anaconda3/lib/python3.11/site-packages/pandas_datareader/wb.py:659: UserWarning: Problem with a World Bank Query
#  Invalid value
#   The provided parameter value is not valid. Indicator: SP.DYN.LEO.IN
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 result_data = pdr.wb.download(indicator = "SP.DYN.LEO.IN", start='1980', end='1999')
#       2 result_data
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas_datareader/wb.py:869, in download(country, indicator, start, end, freq, errors, **kwargs)
#     816 def download(
#     817     country=None,
#     818     indicator=None,
#    (...)
#     823     **kwargs
#     824 ):
#     825     """
#     826     Download data series from the World Bank's World Development Indicators
#     827
#    (...)
#     859         DataFrame with columns country, year, indicator value
#     860     """
#     861     return WorldBankReader(
#     862         symbols=indicator,
#     863         countries=country,
#     864         start=start,
#     865         end=end,
#     866         freq=freq,
#     867         errors=errors,
#     868         **kwargs
# --> 869     ).read()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas_datareader/wb.py:641, in WorldBankReader.read(self)
#     639 """Read data"""
#     640 try:
# --> 641     return self._read()
#     642 finally:
#     643     self.close()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas_datareader/wb.py:671, in WorldBankReader._read(self)
#     669 else:
#     670     msg = "No indicators returned data."
# --> 671     raise ValueError(msg)
#
# ValueError: No indicators returned data.
