# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

plt.style.use('ggplot')
pd.set_option('display.max_columns', None)

df = pd.read_csv('CarPrice_Assignment.csv')
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
# ...

# %% [markdown]
# <h2>Step 1 : Understanding Data</h2>

# %%
df.shape
# Out:
# (205, 26)

# %%
df.head(5)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %% [markdown]
# <h2>Step 2 : Data Preperation</h2>

# %%
df.head(2)
# Out:
#    car_ID  symboling              CarName fueltype aspiration doornumber  \
# 0       1          3   alfa-romero giulia      gas        std        two
# 1       2          3  alfa-romero stelvio      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
#
# [2 rows x 26 columns]

# %%
# Removing useless columns and rewrite
df_selected = df[['car_ID', 
#     'symboling', 
 'CarName', 
 #'fueltype', 
 # 'aspiration',
        'doornumber',
       # 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
       # 'carlength', 'carwidth', 'carheight', 
       #'curbweight', 'enginetype',
       #'cylindernumber', 
       'enginesize', 
       #'fuelsystem', 'boreratio', 'stroke',
       #'compressionratio', 
       'horsepower', 'peakrpm', 'citympg', 'highwaympg',
       'price']].copy()

# %%
# Droping columns which is not important
# df.drop(['car_ID'], axis=1)

# %%
# Rename the columns
df_selected.rename(columns={'car_ID': 'car_id'}, inplace=True)
df_selected.head(2)
# Out:
#    car_id              CarName doornumber  enginesize  horsepower  peakrpm  \
# 0       1   alfa-romero giulia        two         130         111     5000
# 1       2  alfa-romero stelvio        two         130         111     5000
#
#    citympg  highwaympg    price
# 0       21          27  13495.0
# 1       21          27  16500.0

# %%
# Find null value
df_selected.isna().sum()
# Out:
#    car_id              CarName doornumber  enginesize  horsepower  peakrpm  \
# 0       1   alfa-romero giulia        two         130         111     5000
# 1       2  alfa-romero stelvio        two         130         111     5000
#
#    citympg  highwaympg    price
# 0       21          27  13495.0
# 1       21          27  16500.0

# %%
df_selected.loc[df_selected.duplicated()]
# Out:
# Empty DataFrame
# Columns: [car_id, CarName, doornumber, enginesize, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []

# %%
df_selected.loc[df.duplicated('CarName').duplicated()]
# Out:
#      car_id                   CarName doornumber  enginesize  horsepower  \
# 1         2       alfa-romero stelvio        two         130         111
# 2         3  alfa-romero Quadrifoglio        two         152         154
# 3         4               audi 100 ls       four         109         102
# 4         5                audi 100ls       four         136         115
# 5         6                  audi fox        two         136         110
# ..      ...                       ...        ...         ...         ...
# 200     201           volvo 145e (sw)       four         141         114
# 201     202               volvo 144ea       four         141         160
# 202     203               volvo 244dl       four         173         134
# 203     204                 volvo 246       four         145         106
# 204     205               volvo 264gl       four         141         114
#
#      peakrpm  citympg  highwaympg    price
# 1       5000       21          27  16500.0
# ...

# %%
# Check for duplicate Car name
df_selected.loc[df_selected.duplicated(subset=['CarName'])].head(5)
# Out:
#     car_id           CarName doornumber  enginesize  horsepower  peakrpm  \
# 6        7        audi 100ls       four         136         110     5500
# 11      12          bmw 320i       four         108         101     5800
# 17      18            bmw x3       four         209         182     5400
# 32      33       honda civic        two          79          60     5500
# 34      35  honda civic cvcc        two          92          76     6000
#
#     citympg  highwaympg    price
# 6        19          25  17710.0
# 11       23          29  16925.0
# 17       15          20  36880.0
# 32       38          42   5399.0
# 34       30          34   7129.0

# %%
df_selected.query('CarName == "honda civic cvcc	"')
# Out:
# Empty DataFrame
# Columns: [car_id, CarName, doornumber, enginesize, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []

# %%
# Check for any duplicate rows in the DataFrame
duplicates = df_selected.duplicated()
print(duplicates)

# To see the actual duplicate rows
print(df_selected[duplicates])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Length: 205, dtype: bool
# Empty DataFrame
# Columns: [car_id, CarName, doornumber, enginesize, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []

# %%
# Check for duplicates based on the 'CarName' column
duplicates_by_carname = df_selected.duplicated(subset=['CarName'])
print(duplicates_by_carname)

# To see the actual duplicate rows based on 'CarName'
print(df_selected[duplicates_by_carname])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200     True
# 201     True
# 202     True
# 203    False
# 204     True
# Length: 205, dtype: bool
#      car_id                  CarName doornumber  enginesize  horsepower  \
# 6         7               audi 100ls       four         136         110
# 11       12                 bmw 320i       four         108         101
# 17       18                   bmw x3       four         209         182
# 32       33              honda civic        two          79          60
# 34       35         honda civic cvcc        two          92          76
# 40       41             honda accord       four         110          86
# 41       42              honda civic       four         110         101
# 46       47             isuzu D-Max         two         119          90
# 59       60                mazda 626        two         122          84
# ...
