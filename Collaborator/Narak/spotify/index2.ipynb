# %%
#spotify-2023.csv
#Loading The Dataset
# EDA and Data Cleaning
#Top 10 Artists Have Most Streamed Songs in 2023
#Top 10 Streamed Songs in 2023
#Relationship Between The Number Of Artists In A Song and Streams In 2023
#Relationship Between Most Streamed Songs And Platforms In 2023
#Relationship Between All Audio Features

# %%
import pandas as pd

# %%
df_ori=pd.read_csv("spotify-2023.csv",encoding="latin-1")
df_ori
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df_ori.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
# EDA and Data Cleaning
#Top 10 Artists Have Most Streamed Songs in 2023
#Top 10 Streamed Songs in 2023
df_ori.shape
# Out:
# (953, 24)

# %%
df_ori.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
df_ori.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
df_ori.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
df = df_ori.copy()
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df['streams'].iloc[573:575]
# Out:
# 573                                            566954746
# 574    BPM110KeyAModeMajorDanceability53Valence75Ener...
# Name: streams, dtype: object

# %%
df.drop(574, inplace=True)

# %%
df['streams']
# Out:
# 0      141381703
# 1      133716286
# 2      140003974
# 3      800840817
# 4      303236322
#          ...
# 948     91473363
# 949    121871870
# 950     73513683
# 951    133895612
# 952     96007391
# Name: streams, Length: 952, dtype: object

# %%
df['streams'] = df['streams'].astype('int64')

# %%
df.sort_values(by = "streams", ascending = False, inplace=True)
df['streams']
# Out:
# 55     3703895074
# 179    3562543890
# 86     2887241814
# 620    2864791672
# 41     2808096550
#           ...
# 68       14780425
# 142      11956641
# 144      11599388
# 393       1365184
# 123          2762
# Name: streams, Length: 952, dtype: int64

# %%
df.head(10)
# Out:
#                                         track_name  \
# 55                                 Blinding Lights
# 179                                   Shape of You
# 86                               Someone You Loved
# 620                                   Dance Monkey
# 41   Sunflower - Spider-Man: Into the Spider-Verse
# 162                                      One Dance
# 84                       STAY (with Justin Bieber)
# 140                                       Believer
# 725                                         Closer
# 48                                         Starboy
#
#                    artist(s)_name  artist_count  released_year  \
# 55                     The Weeknd             1           2019
# 179                    Ed Sheeran             1           2017
# 86                  Lewis Capaldi             1           2018
# 620                   Tones and I             1           2019
# 41          Post Malone, Swae Lee             2           2018
# ...

# %%
df['released_date'] = pd.to_datetime(df['released_year'].astype(str) + "-" + df['released_month'].astype(str) + "-" + df['released_day'].astype(str))
df['released_date']
# Out:
# 55    2019-11-29
# 179   2017-01-06
# 86    2018-11-08
# 620   2019-05-10
# 41    2018-10-09
#          ...
# 68    2023-07-14
# 142   2023-06-01
# 144   2023-07-13
# 393   2022-12-22
# 123   2022-12-09
# Name: released_date, Length: 952, dtype: datetime64[ns]

# %%
year2023 = df.loc[df["released_date"] >= "2023"]
year2023
# Out:
#                                 track_name                artist(s)_name  \
# 12                                 Flowers                   Miley Cyrus
# 6                          Ella Baila Sola    Eslabon Armado, Peso Pluma
# 133  Shakira: Bzrp Music Sessions, Vol. 53             Shakira, Bizarrap
# 34                                     TQG              Karol G, Shakira
# 9                          La Bebe - Remix         Peso Pluma, Yng Lvcas
# ..                                     ...                           ...
# 30                                    Rush                   Troye Sivan
# 58                                     S91                       Karol G
# 68                               Overdrive                   Post Malone
# 142            Gol Bolinha, Gol Quadrado 2           Mc Pedrinho, DJ 900
# 144                                  QUEMA  Sog, Ryan Castro, Peso Pluma
#
#      artist_count  released_year  released_month  released_day  \
# ...

# %%
top_artist = df['artist(s)_name'].value_counts()
top_artist
# Out:
# artist(s)_name
# Taylor Swift                            34
# The Weeknd                              22
# SZA                                     19
# Bad Bunny                               19
# Harry Styles                            17
#                                         ..
# Natanael Cano, Peso Pluma                1
# Chris Brown, Rvssian, Rauw Alejandro     1
# Childish Gambino                         1
# Rï¿½ï                                    1
# Carin Leon, Grupo Frontera               1
# Name: count, Length: 644, dtype: int64

# %%
top10_artist = top_artist.head(10)
top10_artist
# Out:
# artist(s)_name
# Taylor Swift      34
# The Weeknd        22
# SZA               19
# Bad Bunny         19
# Harry Styles      17
# Kendrick Lamar    12
# Morgan Wallen     11
# Ed Sheeran         9
# Feid               8
# BTS                8
# Name: count, dtype: int64

# %%
top_stream = df["track_name"].head(10)
top_stream
# Out:
# 55                                   Blinding Lights
# 179                                     Shape of You
# 86                                 Someone You Loved
# 620                                     Dance Monkey
# 41     Sunflower - Spider-Man: Into the Spider-Verse
# 162                                        One Dance
# 84                         STAY (with Justin Bieber)
# 140                                         Believer
# 725                                           Closer
# 48                                           Starboy
# Name: track_name, dtype: object

# %%
top_stream.reset_index(drop = True, inplace= True)

# %%
top_stream
# Out:
# 0                                  Blinding Lights
# 1                                     Shape of You
# 2                                Someone You Loved
# 3                                     Dance Monkey
# 4    Sunflower - Spider-Man: Into the Spider-Verse
# 5                                        One Dance
# 6                        STAY (with Justin Bieber)
# 7                                         Believer
# 8                                           Closer
# 9                                          Starboy
# Name: track_name, dtype: object

# %%
streams_amount = df['streams'].head(10)
streams_amount
# Out:
# 55     3703895074
# 179    3562543890
# 86     2887241814
# 620    2864791672
# 41     2808096550
# 162    2713922350
# 84     2665343922
# 140    2594040133
# 725    2591224264
# 48     2565529693
# Name: streams, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20, 10))
plt.title("Top most 10 stream songs ")
plt.xlabel("Song Names")
plt.ylabel("Streamings")
plt.xticks(rotation = "vertical")
plt.bar(top_stream.values, streams_amount.values, color = "red")
plt.show()

# %%
top100 = df.iloc[0:100]
top100
# Out:
#                                         track_name         artist(s)_name  \
# 55                                 Blinding Lights             The Weeknd
# 179                                   Shape of You             Ed Sheeran
# 86                               Someone You Loved          Lewis Capaldi
# 620                                   Dance Monkey            Tones and I
# 41   Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
# ..                                             ...                    ...
# 274                                        Shivers             Ed Sheeran
# 401                                        Heather             Conan Gray
# 22                                I Wanna Be Yours         Arctic Monkeys
# 820                                           Iris      The Goo Goo Dolls
# 152                                   Danza Kuduro      Don Omar, Lucenzo
#
#      artist_count  released_year  released_month  released_day  \
# ...

# %%
top100['artist(s)_name'].value_counts
top10_artist
# Out:
# artist(s)_name
# Taylor Swift      34
# The Weeknd        22
# SZA               19
# Bad Bunny         19
# Harry Styles      17
# Kendrick Lamar    12
# Morgan Wallen     11
# Ed Sheeran         9
# Feid               8
# BTS                8
# Name: count, dtype: int64

# %%
top_songs_ofartists = top100['artist(s)_name'].value_counts()
top10_artist_songs = top_songs_ofartists.head(10)

# %%
import seaborn as sns

plt.figure(figsize= (15, 10))

sns.barplot( x = top10_artist_songs.index, y = top10_artist_songs.values, palette= 'Paired')

plt.title('Top 10 Artist with most streamed songs')
plt.xlabel('artists')
plt.ylabel('numbers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11552\2660056014.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot( x = top10_artist_songs.index, y = top10_artist_songs.values, palette= 'Paired')

# %%
top_ = df.head(10)
song_ = df.head(100)
top_
# Out:
#                                         track_name  \
# 55                                 Blinding Lights
# 179                                   Shape of You
# 86                               Someone You Loved
# 620                                   Dance Monkey
# 41   Sunflower - Spider-Man: Into the Spider-Verse
# 162                                      One Dance
# 84                       STAY (with Justin Bieber)
# 140                                       Believer
# 725                                         Closer
# 48                                         Starboy
#
#                    artist(s)_name  artist_count  released_year  \
# 55                     The Weeknd             1           2019
# 179                    Ed Sheeran             1           2017
# 86                  Lewis Capaldi             1           2018
# 620                   Tones and I             1           2019
# 41          Post Malone, Swae Lee             2           2018
# ...

# %%
song_100 = top_['artist(s)_name'].isin(song_['artist(s)_name'])

# %%
song_
# Out:
#                                         track_name         artist(s)_name  \
# 55                                 Blinding Lights             The Weeknd
# 179                                   Shape of You             Ed Sheeran
# 86                               Someone You Loved          Lewis Capaldi
# 620                                   Dance Monkey            Tones and I
# 41   Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
# ..                                             ...                    ...
# 274                                        Shivers             Ed Sheeran
# 401                                        Heather             Conan Gray
# 22                                I Wanna Be Yours         Arctic Monkeys
# 820                                           Iris      The Goo Goo Dolls
# 152                                   Danza Kuduro      Don Omar, Lucenzo
#
#      artist_count  released_year  released_month  released_day  \
# ...

# %%
artists_10 =
# Out:
#   Cell In[333], line 1
#     artists_10 =
#                  ^
# SyntaxError: invalid syntax

# %%
song_artist = song_['artist(s)_name']
song_artist
# Out:
# 55                The Weeknd
# 179               Ed Sheeran
# 86             Lewis Capaldi
# 620              Tones and I
# 41     Post Malone, Swae Lee
#                ...
# 274               Ed Sheeran
# 401               Conan Gray
# 22            Arctic Monkeys
# 820        The Goo Goo Dolls
# 152        Don Omar, Lucenzo
# Name: artist(s)_name, Length: 100, dtype: object

# %%
art = song_artist.loc[song_artist.]

# %%
artist100=song_["artist(s)_name"].value_counts()
artist100.head(10)
# Out:
# artist(s)_name
# Ed Sheeran        6
# The Weeknd        5
# Harry Styles      3
# Bruno Mars        3
# Eminem            3
# Adele             2
# Coldplay          2
# Linkin Park       2
# Olivia Rodrigo    2
# Avicii            2
# Name: count, dtype: int64

# %%
song_10 = song_.iloc[song_[top_]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 song_10 = df.loc[song_['artist(s)_name'] == top_['artist(s)_name']]
#       2 song_10
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11552\3379977555.py in ?()
# ----> 1 top_10_in100.set_index()
#
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'set_index'

# %%
import seaborn as sns

plt.figure(figsize= (15, 10))

sns.barplot( y = top_10_in100.index, x = top_10_in100.values, palette= 'Paired')

plt.title('Top 10 Artist with most streamed songs')
plt.ylabel('artists')
plt.xlabel('numbers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11552\90484348.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot( y = top_10_in100.index, x = top_10_in100.values, palette= 'Paired')

# %%
df
# Out:
#                                         track_name  \
# 55                                 Blinding Lights
# 179                                   Shape of You
# 86                               Someone You Loved
# 620                                   Dance Monkey
# 41   Sunflower - Spider-Man: Into the Spider-Verse
# ..                                             ...
# 68                                       Overdrive
# 142                    Gol Bolinha, Gol Quadrado 2
# 144                                          QUEMA
# 393                              Jhoome Jo Pathaan
# 123                                    Que Vuelvas
#
#                                         artist(s)_name  artist_count  \
# 55                                          The Weeknd             1
# 179                                         Ed Sheeran             1
# 86                                       Lewis Capaldi             1
# 620                                        Tones and I             1
# ...

# %%
top100 = df.head(100)
top10 = df.head(10)

# %%
top100
# Out:
#                                         track_name         artist(s)_name  \
# 55                                 Blinding Lights             The Weeknd
# 179                                   Shape of You             Ed Sheeran
# 86                               Someone You Loved          Lewis Capaldi
# 620                                   Dance Monkey            Tones and I
# 41   Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
# ..                                             ...                    ...
# 274                                        Shivers             Ed Sheeran
# 401                                        Heather             Conan Gray
# 22                                I Wanna Be Yours         Arctic Monkeys
# 820                                           Iris      The Goo Goo Dolls
# 152                                   Danza Kuduro      Don Omar, Lucenzo
#
#      artist_count  released_year  released_month  released_day  \
# ...

# %%
top10
# Out:
#                                         track_name  \
# 55                                 Blinding Lights
# 179                                   Shape of You
# 86                               Someone You Loved
# 620                                   Dance Monkey
# 41   Sunflower - Spider-Man: Into the Spider-Verse
# 162                                      One Dance
# 84                       STAY (with Justin Bieber)
# 140                                       Believer
# 725                                         Closer
# 48                                         Starboy
#
#                    artist(s)_name  artist_count  released_year  \
# 55                     The Weeknd             1           2019
# 179                    Ed Sheeran             1           2017
# 86                  Lewis Capaldi             1           2018
# 620                   Tones and I             1           2019
# 41          Post Malone, Swae Lee             2           2018
# ...

# %%
# result = top100[top100['artist(s)_name'].isin(top10['artist(s)_name)'].index)]
# result

# %%
filter_most_streamed_artist = df[['artist(s)_name','streams']]
filter_most_streamed_artist
# Out:
#                                         artist(s)_name     streams
# 55                                          The Weeknd  3703895074
# 179                                         Ed Sheeran  3562543890
# 86                                       Lewis Capaldi  2887241814
# 620                                        Tones and I  2864791672
# 41                               Post Malone, Swae Lee  2808096550
# ..                                                 ...         ...
# 68                                         Post Malone    14780425
# 142                                Mc Pedrinho, DJ 900    11956641
# 144                       Sog, Ryan Castro, Peso Pluma    11599388
# 393  Arijit Singh, Vishal Dadlani, Sukriti Kakar, V...     1365184
# 123                         Carin Leon, Grupo Frontera        2762
#
# [952 rows x 2 columns]

# %%
# Top 100 
top_100_most_streamed_song_ = filter_most_streamed_artist.head(100)
top_100_most_streamed_song_
# Out:
#             artist(s)_name     streams
# 55              The Weeknd  3703895074
# 179             Ed Sheeran  3562543890
# 86           Lewis Capaldi  2887241814
# 620            Tones and I  2864791672
# 41   Post Malone, Swae Lee  2808096550
# ..                     ...         ...
# 274             Ed Sheeran  1302184087
# 401             Conan Gray  1301799902
# 22          Arctic Monkeys  1297026226
# 820      The Goo Goo Dolls  1284942608
# 152      Don Omar, Lucenzo  1279434863
#
# [100 rows x 2 columns]

# %%
# Top 10 most streamed artist.

top_10_most_streamed_song_ = filter_most_streamed_artist.head(10)
top_10_most_streamed_song_
# Out:
#                    artist(s)_name     streams
# 55                     The Weeknd  3703895074
# 179                    Ed Sheeran  3562543890
# 86                  Lewis Capaldi  2887241814
# 620                   Tones and I  2864791672
# 41          Post Malone, Swae Lee  2808096550
# 162           Drake, WizKid, Kyla  2713922350
# 84   Justin Bieber, The Kid Laroi  2665343922
# 140               Imagine Dragons  2594040133
# 725      The Chainsmokers, Halsey  2591224264
# 48          The Weeknd, Daft Punk  2565529693

# %%
# top_10_most_streamed_song_.values

# %%
filter_10_most_streamed_artist_in_100 = top_100_most_streamed_song_[top_100_most_streamed_song_['artist(s)_name'].isin(top_10_most_streamed_song_['artist(s)_name'])]
c = filter_10_most_streamed_artist_in_100['artist(s)_name'].value_counts()
c
# Out:
# artist(s)_name
# Ed Sheeran                      6
# The Weeknd                      5
# Lewis Capaldi                   2
# Imagine Dragons                 2
# Tones and I                     1
# Post Malone, Swae Lee           1
# Drake, WizKid, Kyla             1
# Justin Bieber, The Kid Laroi    1
# The Chainsmokers, Halsey        1
# The Weeknd, Daft Punk           1
# Name: count, dtype: int64

# %%
top10 = c.head(10)
top10
# Out:
# artist(s)_name
# Ed Sheeran                      6
# The Weeknd                      5
# Lewis Capaldi                   2
# Imagine Dragons                 2
# Tones and I                     1
# Post Malone, Swae Lee           1
# Drake, WizKid, Kyla             1
# Justin Bieber, The Kid Laroi    1
# The Chainsmokers, Halsey        1
# The Weeknd, Daft Punk           1
# Name: count, dtype: int64

# %%
import seaborn as sns

plt.figure(figsize= (15, 10))

sns.barplot( y = top10.index, x = top10.values, palette= 'Paired')

plt.title('Top 10 Artist with most streamed songs')
plt.ylabel('artists')
plt.xlabel('numbers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11552\1937251075.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot( y = top10.index, x = top10.values, palette= 'Paired')

# %%
df
# Out:
#                                         track_name  \
# 55                                 Blinding Lights
# 179                                   Shape of You
# 86                               Someone You Loved
# 620                                   Dance Monkey
# 41   Sunflower - Spider-Man: Into the Spider-Verse
# ..                                             ...
# 68                                       Overdrive
# 142                    Gol Bolinha, Gol Quadrado 2
# 144                                          QUEMA
# 393                              Jhoome Jo Pathaan
# 123                                    Que Vuelvas
#
#                                         artist(s)_name  artist_count  \
# 55                                          The Weeknd             1
# 179                                         Ed Sheeran             1
# 86                                       Lewis Capaldi             1
# 620                                        Tones and I             1
# ...

# %%
top_
# Out:
#                                         track_name  \
# 55                                 Blinding Lights
# 179                                   Shape of You
# 86                               Someone You Loved
# 620                                   Dance Monkey
# 41   Sunflower - Spider-Man: Into the Spider-Verse
# 162                                      One Dance
# 84                       STAY (with Justin Bieber)
# 140                                       Believer
# 725                                         Closer
# 48                                         Starboy
#
#                    artist(s)_name  artist_count  released_year  \
# 55                     The Weeknd             1           2019
# 179                    Ed Sheeran             1           2017
# 86                  Lewis Capaldi             1           2018
# 620                   Tones and I             1           2019
# 41          Post Malone, Swae Lee             2           2018
# ...

# %%
song_
# Out:
#                                         track_name         artist(s)_name  \
# 55                                 Blinding Lights             The Weeknd
# 179                                   Shape of You             Ed Sheeran
# 86                               Someone You Loved          Lewis Capaldi
# 620                                   Dance Monkey            Tones and I
# 41   Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
# ..                                             ...                    ...
# 274                                        Shivers             Ed Sheeran
# 401                                        Heather             Conan Gray
# 22                                I Wanna Be Yours         Arctic Monkeys
# 820                                           Iris      The Goo Goo Dolls
# 152                                   Danza Kuduro      Don Omar, Lucenzo
#
#      artist_count  released_year  released_month  released_day  \
# ...

# %%
top = song_['artist(s)_name'].value_counts()
top.head(10)
# Out:
# artist(s)_name
# Ed Sheeran        6
# The Weeknd        5
# Harry Styles      3
# Bruno Mars        3
# Eminem            3
# Adele             2
# Coldplay          2
# Linkin Park       2
# Olivia Rodrigo    2
# Avicii            2
# Name: count, dtype: int64

# %%
df
# Out:
#                                         track_name  \
# 55                                 Blinding Lights
# 179                                   Shape of You
# 86                               Someone You Loved
# 620                                   Dance Monkey
# 41   Sunflower - Spider-Man: Into the Spider-Verse
# ..                                             ...
# 68                                       Overdrive
# 142                    Gol Bolinha, Gol Quadrado 2
# 144                                          QUEMA
# 393                              Jhoome Jo Pathaan
# 123                                    Que Vuelvas
#
#                                         artist(s)_name  artist_count  \
# 55                                          The Weeknd             1
# 179                                         Ed Sheeran             1
# 86                                       Lewis Capaldi             1
# 620                                        Tones and I             1
# ...

# %%
top1 = df['artist(s)_name']
top2 = top1.head(10)
top2
# Out:
# 55                       The Weeknd
# 179                      Ed Sheeran
# 86                    Lewis Capaldi
# 620                     Tones and I
# 41            Post Malone, Swae Lee
# 162             Drake, WizKid, Kyla
# 84     Justin Bieber, The Kid Laroi
# 140                 Imagine Dragons
# 725        The Chainsmokers, Halsey
# 48            The Weeknd, Daft Punk
# Name: artist(s)_name, dtype: object

# %%
song1 = df.head(100)
song1
# Out:
#                                         track_name         artist(s)_name  \
# 55                                 Blinding Lights             The Weeknd
# 179                                   Shape of You             Ed Sheeran
# 86                               Someone You Loved          Lewis Capaldi
# 620                                   Dance Monkey            Tones and I
# 41   Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
# ..                                             ...                    ...
# 274                                        Shivers             Ed Sheeran
# 401                                        Heather             Conan Gray
# 22                                I Wanna Be Yours         Arctic Monkeys
# 820                                           Iris      The Goo Goo Dolls
# 152                                   Danza Kuduro      Don Omar, Lucenzo
#
#      artist_count  released_year  released_month  released_day  \
# ...

# %%
top = song1['artist(s)_name'].value_counts()
top
# Out:
# artist(s)_name
# Ed Sheeran                6
# The Weeknd                5
# Harry Styles              3
# Bruno Mars                3
# Eminem                    3
#                          ..
# Bad Bunny, Jhay Cortez    1
# Maroon 5                  1
# Chris Molitor             1
# Lil Nas X                 1
# Don Omar, Lucenzo         1
# Name: count, Length: 77, dtype: int64

# %%
top10 = top.head(10)
top10
# Out:
# artist(s)_name
# Ed Sheeran        6
# The Weeknd        5
# Harry Styles      3
# Bruno Mars        3
# Eminem            3
# Adele             2
# Coldplay          2
# Linkin Park       2
# Olivia Rodrigo    2
# Avicii            2
# Name: count, dtype: int64

# %%
import seaborn as sns

plt.figure(figsize= (15, 10))

sns.barplot( y = top10.index, x = top10.values, palette= 'Paired')

plt.title('Top 10 Artist with most streamed songs')
plt.ylabel('artists')
plt.xlabel('numbers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11552\1937251075.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot( y = top10.index, x = top10.values, palette= 'Paired')

# %%
df
# Out:
#                                         track_name  \
# 55                                 Blinding Lights
# 179                                   Shape of You
# 86                               Someone You Loved
# 620                                   Dance Monkey
# 41   Sunflower - Spider-Man: Into the Spider-Verse
# ..                                             ...
# 68                                       Overdrive
# 142                    Gol Bolinha, Gol Quadrado 2
# 144                                          QUEMA
# 393                              Jhoome Jo Pathaan
# 123                                    Que Vuelvas
#
#                                         artist(s)_name  artist_count  \
# 55                                          The Weeknd             1
# 179                                         Ed Sheeran             1
# 86                                       Lewis Capaldi             1
# 620                                        Tones and I             1
# ...

# %%
artist = df['artist(s)_name']
artist
# Out:
# 55                                            The Weeknd
# 179                                           Ed Sheeran
# 86                                         Lewis Capaldi
# 620                                          Tones and I
# 41                                 Post Malone, Swae Lee
#                              ...
# 68                                           Post Malone
# 142                                  Mc Pedrinho, DJ 900
# 144                         Sog, Ryan Castro, Peso Pluma
# 393    Arijit Singh, Vishal Dadlani, Sukriti Kakar, V...
# 123                           Carin Leon, Grupo Frontera
# Name: artist(s)_name, Length: 952, dtype: object

# %%
art10 = artist.head(10)
art10
# Out:
# 55                       The Weeknd
# 179                      Ed Sheeran
# 86                    Lewis Capaldi
# 620                     Tones and I
# 41            Post Malone, Swae Lee
# 162             Drake, WizKid, Kyla
# 84     Justin Bieber, The Kid Laroi
# 140                 Imagine Dragons
# 725        The Chainsmokers, Halsey
# 48            The Weeknd, Daft Punk
# Name: artist(s)_name, dtype: object

# %%
song_100 = df.head(100)
song_100
# Out:
#                                         track_name         artist(s)_name  \
# 55                                 Blinding Lights             The Weeknd
# 179                                   Shape of You             Ed Sheeran
# 86                               Someone You Loved          Lewis Capaldi
# 620                                   Dance Monkey            Tones and I
# 41   Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
# ..                                             ...                    ...
# 274                                        Shivers             Ed Sheeran
# 401                                        Heather             Conan Gray
# 22                                I Wanna Be Yours         Arctic Monkeys
# 820                                           Iris      The Goo Goo Dolls
# 152                                   Danza Kuduro      Don Omar, Lucenzo
#
#      artist_count  released_year  released_month  released_day  \
# ...

# %%
song_1 = song_100['artist(s)_name'].value_counts()
song_1
# Out:
# artist(s)_name
# Ed Sheeran                6
# The Weeknd                5
# Harry Styles              3
# Bruno Mars                3
# Eminem                    3
#                          ..
# Bad Bunny, Jhay Cortez    1
# Maroon 5                  1
# Chris Molitor             1
# Lil Nas X                 1
# Don Omar, Lucenzo         1
# Name: count, Length: 77, dtype: int64

# %%
song_1_10 = song_1.head(10)
song_1_10
# Out:
# artist(s)_name
# Ed Sheeran        6
# The Weeknd        5
# Harry Styles      3
# Bruno Mars        3
# Eminem            3
# Adele             2
# Coldplay          2
# Linkin Park       2
# Olivia Rodrigo    2
# Avicii            2
# Name: count, dtype: int64

# %%
import seaborn as sns

plt.figure(figsize= (15, 10))

sns.barplot( y = song_1_10.index, x = song_1_10.values, palette= 'Paired')

plt.title('Top 10 Artist with most streamed songs')
plt.ylabel('artists')
plt.xlabel('numbers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11552\1682111361.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot( y = song_1_10.index, x = song_1_10.values, palette= 'Paired')
