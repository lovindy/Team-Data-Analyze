# %%
#spotify-2023.csv
import pandas as pd
df_ori = pd.read_csv('spotify-2023.csv', encoding="latin-1")
df_ori
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df_ori.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df_ori.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
df_ori.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
df_ori.shape
# Out:
# (953, 24)

# %%
df_ori.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
df_ori.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
df_ori.duplicated().sum()
# Out:
# 0

# %%
df=df_ori.copy()
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
mode_key = df['key'].mode()[0]

df['key'].fillna(mode_key, inplace=True)
df['key'].isnull().sum()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10484\616534566.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['key'].fillna(mode_key, inplace=True)
# 0

# %%
df['streams'].sort_values(ascending=False)
# Out:
# 33      999748277
# 625     991336132
# 253     988515741
# 455      98709329
# 98      983637508
#           ...
# 366    1022258230
# 744     101780047
# 515     101114984
# 500    1007612429
# 301     100409613
# Name: streams, Length: 952, dtype: object

# %%
df.drop(574, inplace=True)

# %%
df['streams'] = df['streams'].astype('int64')
# Out:
# 0      141381703
# 1      133716286
# 2      140003974
# 3      800840817
# 4      303236322
#          ...
# 948     91473363
# 949    121871870
# 950     73513683
# 951    133895612
# 952     96007391
# Name: streams, Length: 952, dtype: int64

# %%
df.sort_values( by='streams', ascending=False, inplace=True)

# %%
df['streams']
# Out:
# 0      141381703
# 1      133716286
# 2      140003974
# 3      800840817
# 4      303236322
#          ...
# 948     91473363
# 949    121871870
# 950     73513683
# 951    133895612
# 952     96007391
# Name: streams, Length: 952, dtype: int64

# %%
df.head()
# Out:
#                                         track_name         artist(s)_name  \
# 55                                 Blinding Lights             The Weeknd
# 179                                   Shape of You             Ed Sheeran
# 86                               Someone You Loved          Lewis Capaldi
# 620                                   Dance Monkey            Tones and I
# 41   Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
#
#      artist_count  released_year  released_month  released_day  \
# 55              1           2019              11            29
# 179             1           2017               1             6
# 86              1           2018              11             8
# 620             1           2019               5            10
# 41              2           2018              10             9
#
#      in_spotify_playlists  in_spotify_charts     streams  in_apple_playlists  \
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                         track_name  \
# 0                                  Blinding Lights
# 1                                     Shape of You
# 2                                Someone You Loved
# 3                                     Dance Monkey
# 4    Sunflower - Spider-Man: Into the Spider-Verse
# ..                                             ...
# 947                                      Overdrive
# 948                    Gol Bolinha, Gol Quadrado 2
# 949                                          QUEMA
# 950                              Jhoome Jo Pathaan
# 951                                    Que Vuelvas
#
#                                         artist(s)_name  artist_count  \
# 0                                           The Weeknd             1
# 1                                           Ed Sheeran             1
# 2                                        Lewis Capaldi             1
# 3                                          Tones and I             1
# ...

# %%
#top 10 most popular songs
top_10 = df.head(10)
top_10
# Out:
#                                       track_name  \
# 0                                Blinding Lights
# 1                                   Shape of You
# 2                              Someone You Loved
# 3                                   Dance Monkey
# 4  Sunflower - Spider-Man: Into the Spider-Verse
# 5                                      One Dance
# 6                      STAY (with Justin Bieber)
# 7                                       Believer
# 8                                         Closer
# 9                                        Starboy
#
#                  artist(s)_name  artist_count  released_year  released_month  \
# 0                    The Weeknd             1           2019              11
# 1                    Ed Sheeran             1           2017               1
# 2                 Lewis Capaldi             1           2018              11
# 3                   Tones and I             1           2019               5
# ...

# %%
top_10_selected = df[['track_name', 'artist(s)_name', 'streams']].head(10)
top_10_selected
# Out:
#                                       track_name  \
# 0                                Blinding Lights
# 1                                   Shape of You
# 2                              Someone You Loved
# 3                                   Dance Monkey
# 4  Sunflower - Spider-Man: Into the Spider-Verse
# 5                                      One Dance
# 6                      STAY (with Justin Bieber)
# 7                                       Believer
# 8                                         Closer
# 9                                        Starboy
#
#                  artist(s)_name     streams
# 0                    The Weeknd  3703895074
# 1                    Ed Sheeran  3562543890
# 2                 Lewis Capaldi  2887241814
# 3                   Tones and I  2864791672
# 4         Post Malone, Swae Lee  2808096550
# 5           Drake, WizKid, Kyla  2713922350
# 6  Justin Bieber, The Kid Laroi  2665343922
# 7               Imagine Dragons  2594040133
# ...

# %%
top_10_selected['streams'].sum()
# Out:
# 28956629362

# %%
trending_ = df.head(100)
trending_
# Out:
#                                        track_name         artist(s)_name  \
# 0                                 Blinding Lights             The Weeknd
# 1                                    Shape of You             Ed Sheeran
# 2                               Someone You Loved          Lewis Capaldi
# 3                                    Dance Monkey            Tones and I
# 4   Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
# ..                                            ...                    ...
# 95                                        Shivers             Ed Sheeran
# 96                                        Heather             Conan Gray
# 97                               I Wanna Be Yours         Arctic Monkeys
# 98                                           Iris      The Goo Goo Dolls
# 99                                   Danza Kuduro      Don Omar, Lucenzo
#
#     artist_count  released_year  released_month  released_day  \
# ...

# %%
famous_artist = trending_['artist(s)_name'].value_counts()
famous_artist
# Out:
# artist(s)_name
# Ed Sheeran                6
# The Weeknd                5
# Harry Styles              3
# Bruno Mars                3
# Eminem                    3
#                          ..
# Bad Bunny, Jhay Cortez    1
# Maroon 5                  1
# Chris Molitor             1
# Lil Nas X                 1
# Don Omar, Lucenzo         1
# Name: count, Length: 77, dtype: int64

# %%
trending_['artist(s)_name'].mode()
# Out:
# 0    Ed Sheeran
# Name: artist(s)_name, dtype: object

# %%
trending_['key']
# Out:
# 0     C#
# 1     C#
# 2     C#
# 3     F#
# 4      D
#       ..
# 95     D
# 96     F
# 97    C#
# 98     B
# 99    C#
# Name: key, Length: 100, dtype: object

# %%
trending_['key'].value_counts()
# Out:
# key
# C#    28
# F     11
# D     10
# B      9
# F#     8
# G#     8
# G      7
# E      7
# A#     5
# D#     4
# A      3
# Name: count, dtype: int64

# %%
trending_['key'][trending_['key'] =='B'].count()
# Out:
# 9

# %%
song_key_b_ = trending_[trending_['key'] == 'B']

# %%
song_key_b_.head(5)
# Out:
#                   track_name              artist(s)_name  artist_count  \
# 11                Heat Waves               Glass Animals             1
# 17           Don't Start Now                    Dua Lipa             1
# 18              Lucid Dreams                  Juice WRLD             1
# 22  Something Just Like This  The Chainsmokers, Coldplay             2
# 47                  Memories                    Maroon 5             1
#
#     released_year  released_month  released_day  in_spotify_playlists  \
# 11           2020               6            28                 22543
# 17           2019              10            31                 27119
# 18           2017               6            15                 14749
# 22           2017               2            22                 23375
# 47           2019               9            20                  9974
#
#     in_spotify_charts     streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
song_key_b_ .reset_index(drop = True)
# Out:
#                  track_name              artist(s)_name  artist_count  \
# 0                Heat Waves               Glass Animals             1
# 1           Don't Start Now                    Dua Lipa             1
# 2              Lucid Dreams                  Juice WRLD             1
# 3  Something Just Like This  The Chainsmokers, Coldplay             2
# 4                  Memories                    Maroon 5             1
# 5                    Yellow               Chris Molitor             1
# 6                Bad Habits                  Ed Sheeran             1
# 7                    Beggin                   Mï¿½ï¿½ne             1
# 8                      Iris           The Goo Goo Dolls             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2020               6            28                 22543
# 1           2019              10            31                 27119
# ...

# %%
song_key_b_ .head()
# Out:
#                  track_name              artist(s)_name  artist_count  \
# 0                Heat Waves               Glass Animals             1
# 1           Don't Start Now                    Dua Lipa             1
# 2              Lucid Dreams                  Juice WRLD             1
# 3  Something Just Like This  The Chainsmokers, Coldplay             2
# 4                  Memories                    Maroon 5             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2020               6            28                 22543
# 1           2019              10            31                 27119
# 2           2017               6            15                 14749
# 3           2017               2            22                 23375
# 4           2019               9            20                  9974
#
#    in_spotify_charts     streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

trending_
# Out:
#                                        track_name         artist(s)_name  \
# 0                                 Blinding Lights             The Weeknd
# 1                                    Shape of You             Ed Sheeran
# 2                               Someone You Loved          Lewis Capaldi
# 3                                    Dance Monkey            Tones and I
# 4   Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
# ..                                            ...                    ...
# 95                                        Shivers             Ed Sheeran
# 96                                        Heather             Conan Gray
# 97                               I Wanna Be Yours         Arctic Monkeys
# 98                                           Iris      The Goo Goo Dolls
# 99                                   Danza Kuduro      Don Omar, Lucenzo
#
#     artist_count  released_year  released_month  released_day  \
# ...

# %%
famous_artist
# Out:
# artist(s)_name
# Ed Sheeran                6
# The Weeknd                5
# Harry Styles              3
# Bruno Mars                3
# Eminem                    3
#                          ..
# Bad Bunny, Jhay Cortez    1
# Maroon 5                  1
# Chris Molitor             1
# Lil Nas X                 1
# Don Omar, Lucenzo         1
# Name: count, Length: 77, dtype: int64

# %%
plt.figure(figsize=(20,10))
plt.xlabel('Artist Name')
plt.ylabel('track amount')
plt.title("artist and track")
plt.xticks(rotation=90)
plt.bar(famous_artist.index, famous_artist.values)
# Out:
# <BarContainer object of 77 artists>

# %%
df.head()
# Out:
#                                       track_name         artist(s)_name  \
# 0                                Blinding Lights             The Weeknd
# 1                                   Shape of You             Ed Sheeran
# 2                              Someone You Loved          Lewis Capaldi
# 3                                   Dance Monkey            Tones and I
# 4  Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
#
#    artist_count  released_year  released_month  released_day  \
# 0             1           2019              11            29
# 1             1           2017               1             6
# 2             1           2018              11             8
# 3             1           2019               5            10
# 4             2           2018              10             9
#
#    in_spotify_playlists  in_spotify_charts     streams  in_apple_playlists  \
# 0                 43899                 69  3703895074                 672
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 952 entries, 0 to 951
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            952 non-null    object
#  1   artist(s)_name        952 non-null    object
#  2   artist_count          952 non-null    int64
#  3   released_year         952 non-null    int64
#  4   released_month        952 non-null    int64
#  5   released_day          952 non-null    int64
#  6   in_spotify_playlists  952 non-null    int64
#  7   in_spotify_charts     952 non-null    int64
#  8   streams               952 non-null    int64
#  9   in_apple_playlists    952 non-null    int64
#  10  in_apple_charts       952 non-null    int64
#  11  in_deezer_playlists   952 non-null    object
#  12  in_deezer_charts      952 non-null    int64
#  13  in_shazam_charts      902 non-null    object
#  14  bpm                   952 non-null    int64
# ...

# %%
df['released_date'] = pd.to_datetime(df['released_year'].astype(str) + "-" + df['released_month'].astype(str) + "-" + df['released_day'].astype(str))
df['released_date']
# Out:
# 0     2019-11-29
# 1     2017-01-06
# 2     2018-11-08
# 3     2019-05-10
# 4     2018-10-09
#          ...
# 947   2023-07-14
# 948   2023-06-01
# 949   2023-07-13
# 950   2022-12-22
# 951   2022-12-09
# Name: released_date, Length: 952, dtype: datetime64[ns]

# %% [markdown]
# df

# %%
df
# Out:
#                                         track_name  \
# 0                                  Blinding Lights
# 1                                     Shape of You
# 2                                Someone You Loved
# 3                                     Dance Monkey
# 4    Sunflower - Spider-Man: Into the Spider-Verse
# ..                                             ...
# 947                                      Overdrive
# 948                    Gol Bolinha, Gol Quadrado 2
# 949                                          QUEMA
# 950                              Jhoome Jo Pathaan
# 951                                    Que Vuelvas
#
#                                         artist(s)_name  artist_count  \
# 0                                           The Weeknd             1
# 1                                           Ed Sheeran             1
# 2                                        Lewis Capaldi             1
# 3                                          Tones and I             1
# ...

# %%
df.drop(["released_year","released_month", "released_day"], axis=1 , inplace=True)
df
# Out:
#                                         track_name  \
# 0                                  Blinding Lights
# 1                                     Shape of You
# 2                                Someone You Loved
# 3                                     Dance Monkey
# 4    Sunflower - Spider-Man: Into the Spider-Verse
# ..                                             ...
# 947                                      Overdrive
# 948                    Gol Bolinha, Gol Quadrado 2
# 949                                          QUEMA
# 950                              Jhoome Jo Pathaan
# 951                                    Que Vuelvas
#
#                                         artist(s)_name  artist_count  \
# 0                                           The Weeknd             1
# 1                                           Ed Sheeran             1
# 2                                        Lewis Capaldi             1
# 3                                          Tones and I             1
# ...

# %%
df.head()
# Out:
#                                       track_name         artist(s)_name  \
# 0                                Blinding Lights             The Weeknd
# 1                                   Shape of You             Ed Sheeran
# 2                              Someone You Loved          Lewis Capaldi
# 3                                   Dance Monkey            Tones and I
# 4  Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
#
#    artist_count  in_spotify_playlists  in_spotify_charts     streams  \
# 0             1                 43899                 69  3703895074
# 1             1                 32181                 10  3562543890
# 2             1                 17836                 53  2887241814
# 3             1                 24529                  0  2864791672
# 4             2                 24094                 78  2808096550
#
#    in_apple_playlists  in_apple_charts in_deezer_playlists  in_deezer_charts  \
# ...

# %%
year2023 = df.loc[df.released_date >= '2023-01-01']
year2023
# Out:
#                                 track_name                artist(s)_name  \
# 92                                 Flowers                   Miley Cyrus
# 213                        Ella Baila Sola    Eslabon Armado, Peso Pluma
# 217  Shakira: Bzrp Music Sessions, Vol. 53             Shakira, Bizarrap
# 254                                    TQG              Karol G, Shakira
# 287                        La Bebe - Remix         Peso Pluma, Yng Lvcas
# ..                                     ...                           ...
# 945                                   Rush                   Troye Sivan
# 946                                    S91                       Karol G
# 947                              Overdrive                   Post Malone
# 948            Gol Bolinha, Gol Quadrado 2           Mc Pedrinho, DJ 900
# 949                                  QUEMA  Sog, Ryan Castro, Peso Pluma
#
#      artist_count  in_spotify_playlists  in_spotify_charts     streams  \
# ...

# %%
#mode bpm 
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%',
#        'released_date'],
#       dtype='object')

# %%
df.drop(["mode","bpm"], axis=1, inplace=True)

# %%
df_unique = df.drop_duplicates(subset = 'track_name', inplace = True)
df_unique

# %%
df['track_name'].duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(df['track_name'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10484\424392141.py in ?()
# ----> 1 df.drop_duplicates(df['track_name'], inplace=True)
#
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, subset, keep, inplace, ignore_index)
#    6814
#    6815         inplace = validate_bool_kwarg(inplace, "inplace")
#    6816         ignore_index = validate_bool_kwarg(ignore_index, "ignore_index")
#    6817
# -> 6818         result = self[-self.duplicated(subset, keep=keep)]
#    6819         if ignore_index:
#    6820             result.index = default_index(len(result))
#    6821
#
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, subset, keep)
#    6946         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
# ...

# %%
df['track_name'].duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#                                         track_name  \
# 0                                  Blinding Lights
# 1                                     Shape of You
# 2                                Someone You Loved
# 3                                     Dance Monkey
# 4    Sunflower - Spider-Man: Into the Spider-Verse
# ..                                             ...
# 947                                      Overdrive
# 948                    Gol Bolinha, Gol Quadrado 2
# 949                                          QUEMA
# 950                              Jhoome Jo Pathaan
# 951                                    Que Vuelvas
#
#                                         artist(s)_name  artist_count  \
# 0                                           The Weeknd             1
# 1                                           Ed Sheeran             1
# 2                                        Lewis Capaldi             1
# 3                                          Tones and I             1
# ...

# %%
year2023
# Out:
#                                 track_name                artist(s)_name  \
# 92                                 Flowers                   Miley Cyrus
# 213                        Ella Baila Sola    Eslabon Armado, Peso Pluma
# 217  Shakira: Bzrp Music Sessions, Vol. 53             Shakira, Bizarrap
# 254                                    TQG              Karol G, Shakira
# 287                        La Bebe - Remix         Peso Pluma, Yng Lvcas
# ..                                     ...                           ...
# 945                                   Rush                   Troye Sivan
# 946                                    S91                       Karol G
# 947                              Overdrive                   Post Malone
# 948            Gol Bolinha, Gol Quadrado 2           Mc Pedrinho, DJ 900
# 949                                  QUEMA  Sog, Ryan Castro, Peso Pluma
#
#      artist_count  in_spotify_playlists  in_spotify_charts     streams  \
# ...

# %%
top10_2023 = year2023['artist(s)_name'].value_counts()

# %% [markdown]
# df.head(10)

# %%
ten_artists = top10_2023.head()

# %%
plt.figure(figsize=(15, 10))
plt.title('Top 10 most streamed song in 2023')
plt.bar(ten_artists.index, ten_artists.values)
plt.xticks(rotation=45)
plt.show()

# %%
song10_2023 = year2023['track_name'].head(10)
song10_2023
# Out:
# 92                                   Flowers
# 213                          Ella Baila Sola
# 217    Shakira: Bzrp Music Sessions, Vol. 53
# 254                                      TQG
# 287                          La Bebe - Remix
# 299                      Die For You - Remix
# 304                                un x100to
# 311                        Cupid - Twin Ver.
# 343                                      PRC
# 347                                      OMG
# Name: track_name, dtype: object

# %%
most_stream=year2023['streams'].head(10)
most_stream
# Out:
# 92     1316855716
# 213     725980112
# 217     721975598
# 254     618990393
# 287     553634067
# 299     518745108
# 304     505671438
# 311     496795686
# 343     436027885
# 347     430977451
# Name: streams, dtype: int64

# %%
plt.figure(figsize=(15, 10))
plt.title('Most streamed song in 2023')
plt.xticks(rotation=45)
plt.bar(most_stream.index, most_stream.values)
plt.show()

# %%
year2023_10 = year2023.head(10)

# %%
year2023_10.set_index(year2023_10['track_name'], inplace=True)
year2023_10
# Out:
#                                                                   track_name  \
# track_name
# Flowers                                                              Flowers
# Ella Baila Sola                                              Ella Baila Sola
# Shakira: Bzrp Music Sessions, Vol. 53  Shakira: Bzrp Music Sessions, Vol. 53
# TQG                                                                      TQG
# La Bebe - Remix                                              La Bebe - Remix
# Die For You - Remix                                      Die For You - Remix
# un x100to                                                          un x100to
# Cupid - Twin Ver.                                          Cupid - Twin Ver.
# PRC                                                                      PRC
# OMG                                                                      OMG
#
#                                                    artist(s)_name  \
# track_name
# ...

# %%
most_streamed_10_111 = year2023_10['streams']
most_streamed_10_111
# Out:
# track_name
# Flowers                                  1316855716
# Ella Baila Sola                           725980112
# Shakira: Bzrp Music Sessions, Vol. 53     721975598
# TQG                                       618990393
# La Bebe - Remix                           553634067
# Die For You - Remix                       518745108
# un x100to                                 505671438
# Cupid - Twin Ver.                         496795686
# PRC                                       436027885
# OMG                                       430977451
# Name: streams, dtype: int64

# %%
plt.figure(figsize=(15, 10))
plt.title("Most Streamed song in 2023")
plt.xticks(rotation=45)
plt.bar(most_streamed_10_111.index, most_streamed_10_111.values)
plt.show()
