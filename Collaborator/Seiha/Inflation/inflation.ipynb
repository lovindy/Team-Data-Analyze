# %%
import pandas as pd

# %%
df_monthly = pd.read_csv("./Monthly.csv")
df_monthly
# Out:
#            DATE  PPIACO_NBD19130101  CPIAUCSL_NBD19470101  PCE_NBD19590101  \
# 0    2015-01-01          1586.77686            1092.86313       3942.07775
# 1    2015-02-01          1579.33884            1095.63315       3958.37961
# 2    2015-03-01          1582.64463            1098.58473       3977.81771
# 3    2015-04-01          1577.68595            1099.72998       3988.59850
# 4    2015-05-01          1598.34711            1103.35661       4010.25809
# ..          ...                 ...                   ...              ...
# 108  2024-01-01          2076.90909            1441.73650       6216.26919
# 109  2024-02-01          2106.72727            1448.10987       6251.55178
# 110  2024-03-01          2108.39669            1453.58473       6293.27017
# 111  2024-04-01          2125.23140            1458.13315       6301.82947
# 112  2024-05-01          2107.19835            1458.21695       6317.47795
#
# ...

# %%
df_daily = pd.read_csv("./Daily.csv")
df_daily
# Out:
#             DATE DCOILBRENTEU_NBD20001229
# 0     2015-01-02                245.26129
# 1     2015-01-05                226.21789
# 2     2015-01-06                221.96634
# 3     2015-01-07                217.27192
# 4     2015-01-08                218.91054
# ...          ...                      ...
# 2472  2024-06-25                384.45527
# 2473  2024-06-26                379.80514
# 2474  2024-06-27                385.29672
# 2475  2024-06-28                386.44818
# 2476  2024-07-01                383.39238
#
# [2477 rows x 2 columns]

# %%
df_annually = pd.read_csv("./Quarterly.csv")
df_annually
# Out:
#           DATE  GDPDEF_NBD19970101  ECIALLCIV_NBD20010101
# 0   2015-01-01           140.19413              145.92680
# 1   2015-04-01           140.99964              146.16293
# 2   2015-07-01           141.37342              147.10744
# 3   2015-10-01           141.37052              147.93388
# 4   2016-01-01           141.24737              148.76033
# 5   2016-04-01           142.20790              149.58678
# 6   2016-07-01           142.57153              150.41322
# 7   2016-10-01           143.26114              151.23967
# 8   2017-01-01           143.99131              152.18418
# 9   2017-04-01           144.36798              153.12869
# 10  2017-07-01           145.10974              154.19126
# 11  2017-10-01           146.00217              155.13577
# 12  2018-01-01           146.93082              156.31641
# 13  2018-04-01           147.96958              157.37898
# 14  2018-07-01           148.60848              158.55962
# ...

# %%
df_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2477 entries, 0 to 2476
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATE                      2477 non-null   object
#  1   DCOILBRENTEU_NBD20001229  2477 non-null   object
# dtypes: object(2)
# memory usage: 38.8+ KB

# %%
df_annually.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DATE                   37 non-null     object
#  1   GDPDEF_NBD19970101     37 non-null     float64
#  2   ECIALLCIV_NBD20010101  37 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1020.0+ bytes

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# The above exception was the direct cause of the following exception:
#
# ...
