# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataset
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# store to correlation matrix, but there is an error said could not convert string to float: 'No', how to fix it

# Assuming 'tips' DataFrame has columns with numeric and non-numeric data
# Identify numeric columns
numeric_columns = tips.select_dtypes(include=['float64', 'int64']).columns

# Create a new DataFrame with only numeric columns
numeric_tips = tips[numeric_columns]

# Calculate correlation matrix
corr = numeric_tips.corr()
print(corr)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
numeric_columns
# Out:
# Index(['total_bill', 'tip', 'size'], dtype='object')

# %%
plt.figure(figsize=(10, 8))  # Set the figure size
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', center=0)  # Create the heatmap
plt.title('Heatmap of Correlations in Tips Dataset')  # Add a title
plt.show()  # Display the heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the dataset
tips = sns.load_dataset("tips")

# Compute the correlation matrix
numeric_columns = tips.select_dtypes(include=['float64', 'int64']).columns

# Create a new DataFrame with only numeric columns
numeric_tips = tips[numeric_columns]

# Calculate correlation matrix
corr = numeric_tips.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', center=0)
plt.title('Heatmap of Correlations in Tips Dataset')
plt.show()

# %%
import numpy as np
import pandas as pd

# Generate sample data
np.random.seed(0)
x = np.random.rand(100)
y = 2 * x + np.random.normal(0, 0.1, 100)
data = pd.DataFrame({'x': x, 'y': y})

# Compute the correlation matrix
corr = data.corr()

# Plot the heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', center=0)
plt.title('Strong Positive Correlation')
plt.show()

# %%
y = -2 * x + np.random.normal(0, 0.1, 100)
data = pd.DataFrame({'x': x, 'y': y})

# Compute the correlation matrix
corr = data.corr()

# Plot the heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', center=0)
plt.title('Strong Negative Correlation')
plt.show()

# %%
y = np.random.rand(100)
data = pd.DataFrame({'x': x, 'y': y})

# Compute the correlation matrix
corr = data.corr()

# Plot the heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', center=0)
plt.title('Weak Correlation')
plt.show()
